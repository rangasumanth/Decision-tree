# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_excel("Baseball_salary.xlsx")
data
# Out:
#             Unnamed: 0  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       -Andy Allanson    293    66      1    30   29     14      1     293
# 1          -Alan Ashby    315    81      7    24   38     39     14    3449
# 2         -Alvin Davis    479   130     18    66   72     76      3    1624
# 3        -Andre Dawson    496   141     20    65   78     37     11    5628
# 4    -Andres Galarraga    321    87     10    39   42     30      2     396
# ..                 ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      -Willie McGee    497   127      7    65   48     37      5    2703
# 318   -Willie Randolph    492   136      5    76   50     94     12    5511
# 319    -Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     -Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     -Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %%
data.rename(columns={'Unnamed: 0': 'Names'},inplace=True)
data
# Out:
#                  Names  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       -Andy Allanson    293    66      1    30   29     14      1     293
# 1          -Alan Ashby    315    81      7    24   38     39     14    3449
# 2         -Alvin Davis    479   130     18    66   72     76      3    1624
# 3        -Andre Dawson    496   141     20    65   78     37     11    5628
# 4    -Andres Galarraga    321    87     10    39   42     30      2     396
# ..                 ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      -Willie McGee    497   127      7    65   48     37      5    2703
# 318   -Willie Randolph    492   136      5    76   50     94     12    5511
# 319    -Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     -Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     -Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %%
data['Names'] = data['Names'].apply(lambda x: x.strip('-'))
data
# Out:
#                 Names  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  \
# 0       Andy Allanson    293    66      1    30   29     14      1     293
# 1          Alan Ashby    315    81      7    24   38     39     14    3449
# 2         Alvin Davis    479   130     18    66   72     76      3    1624
# 3        Andre Dawson    496   141     20    65   78     37     11    5628
# 4    Andres Galarraga    321    87     10    39   42     30      2     396
# ..                ...    ...   ...    ...   ...  ...    ...    ...     ...
# 317      Willie McGee    497   127      7    65   48     37      5    2703
# 318   Willie Randolph    492   136      5    76   50     94     12    5511
# 319    Wayne Tolleson    475   126      3    61   43     52      6    1700
# 320     Willie Upshaw    573   144      9    85   60     78      8    3198
# 321     Willie Wilson    631   170      9    77   44     31     11    4908
#
# ...

# %%
#Renaming the header
data.rename(columns={'CAtBat':'CareerAtBat','CHits':'CareerHits','CHmRun':'CareerHR','CRuns':'CareerRuns','CRBI':'CareerRBI','CWalks':'CareerWalks'},inplace=True)
data
# Out:
#                 Names  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  \
# 0       Andy Allanson    293    66      1    30   29     14      1
# 1          Alan Ashby    315    81      7    24   38     39     14
# 2         Alvin Davis    479   130     18    66   72     76      3
# 3        Andre Dawson    496   141     20    65   78     37     11
# 4    Andres Galarraga    321    87     10    39   42     30      2
# ..                ...    ...   ...    ...   ...  ...    ...    ...
# 317      Willie McGee    497   127      7    65   48     37      5
# 318   Willie Randolph    492   136      5    76   50     94     12
# 319    Wayne Tolleson    475   126      3    61   43     52      6
# 320     Willie Upshaw    573   144      9    85   60     78      8
# 321     Willie Wilson    631   170      9    77   44     31     11
#
#      CareerAtBat  CareerHits  ...  CareerRuns  CareerRBI  CareerWalks  League  \
# 0            293          66  ...          30         29           14       A
# ...

# %%
data = data.dropna()

# %%
data
# Out:
#                 Names  AtBat  Hits  HmRun  Runs  RBI  Walks  Years  \
# 1          Alan Ashby    315    81      7    24   38     39     14
# 2         Alvin Davis    479   130     18    66   72     76      3
# 3        Andre Dawson    496   141     20    65   78     37     11
# 4    Andres Galarraga    321    87     10    39   42     30      2
# 5     Alfredo Griffin    594   169      4    74   51     35     11
# ..                ...    ...   ...    ...   ...  ...    ...    ...
# 317      Willie McGee    497   127      7    65   48     37      5
# 318   Willie Randolph    492   136      5    76   50     94     12
# 319    Wayne Tolleson    475   126      3    61   43     52      6
# 320     Willie Upshaw    573   144      9    85   60     78      8
# 321     Willie Wilson    631   170      9    77   44     31     11
#
#      CareerAtBat  CareerHits  ...  CareerRuns  CareerRBI  CareerWalks  League  \
# 1           3449         835  ...         321        414          375       N
# ...

# %%
sns.histplot(data.Salary)
# Out:
# <Axes: xlabel='Salary', ylabel='Count'>

# %%
# Assuming your DataFrame is named 'data'
numerical_data = data.select_dtypes(include=['int64', 'float64'])

# Calculate the correlation matrix
correlation_matrix = numerical_data.corr()

# Plotting the correlation matrix as a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['Hits'], data['Salary'], alpha=0.5)
plt.xlabel('Hits')
plt.ylabel('Salary')
plt.title('Scatter Plot between Feature1 and Salary')
plt.show()

# %%
# scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['Hits'], data['Runs'], alpha=0.5)
plt.xlabel('Hits')
plt.ylabel('Salary')
plt.title('Scatter Plot between Feature1 and Salary')
plt.show()

# %%
# Calculate descriptive statistics
descriptive_stats = data.describe()

# Print the descriptive statistics
print(descriptive_stats)
# Out:
#             AtBat        Hits       HmRun        Runs         RBI       Walks  \
# count  263.000000  263.000000  263.000000  263.000000  263.000000  263.000000
# mean   403.642586  107.828897   11.619772   54.745247   51.486692   41.114068
# std    147.307209   45.125326    8.757108   25.539816   25.882714   21.718056
# min     19.000000    1.000000    0.000000    0.000000    0.000000    0.000000
# 25%    282.500000   71.500000    5.000000   33.500000   30.000000   23.000000
# 50%    413.000000  103.000000    9.000000   52.000000   47.000000   37.000000
# 75%    526.000000  141.500000   18.000000   73.000000   71.000000   57.000000
# max    687.000000  238.000000   40.000000  130.000000  121.000000  105.000000
#
#             Years   CareerAtBat   CareerHits    CareerHR   CareerRuns  \
# count  263.000000    263.000000   263.000000  263.000000   263.000000
# mean     7.311787   2657.543726   722.186312   69.239544   361.220532
# ...

# %%
import matplotlib.pyplot as plt

# Plot histograms for each column
data.hist(bins=10, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error
from math import log
from IPython.display import Image
from sklearn.tree import export_graphviz
from six import StringIO
import pydotplus

# Calculate log of the salary and add it as a new column
data['LogSalary'] = data['Salary'].apply(lambda x: log(x))

# Select features and output variable
features = ['CareerAtBat', 'CareerHits', 'CareerHR', 'CareerRuns', 'CareerRBI', 'CareerWalks']
output = 'LogSalary'

# Prepare input (X) and output (y) variables
X = data[features]
y = data[output]
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_8868\2969476890.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['LogSalary'] = data['Salary'].apply(lambda x: log(x))

# %%
regressor = DecisionTreeRegressor()
regressor.fit(X, y)
# Out:
# DecisionTreeRegressor()
